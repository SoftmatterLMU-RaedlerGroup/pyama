# %% [markdown]
# # Test Processing Workflow (Core)
#
# This notebook demonstrates running the core processing workflow without the Qt UI.

# %%
from pathlib import Path
import logging
from pprint import pprint

from pyama_core.io.nikon import load_nd2
from pyama_core.workflow import run_complete_workflow, ProcessingContext

logging.basicConfig(level=logging.INFO)

# %%
# Configure inputs
ND2_PATH = Path("E:/250129_HuH7/250129_HuH7.nd2")  # change me
OUTPUT_DIR = Path("E:/250129_HuH7")
# Select channels by index
PHASE_CONTRAST_CH = 0
FLUORESCENCE_CHS = [1]  # list of ints

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# Load metadata (for verification) and build context
_, md = load_nd2(ND2_PATH)
# pprint(md)

ctx: ProcessingContext = {
    "output_dir": OUTPUT_DIR,
    "channels": {
        "phase_contrast": PHASE_CONTRAST_CH,
        "fluorescence": FLUORESCENCE_CHS,
    },
    "npy_paths": {},
    "params": {},
}
pprint(ctx)
# Out:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}

# %%
# Run the workflow
success = run_complete_workflow(
    metadata=md,
    context=ctx,
    fov_start=0,
    fov_end=1,
    batch_size=2,
    n_workers=2,
)
print("Success:", success)
# Out:
# INFO: Initial context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: Extracting batch: FOVs 0-1
# INFO: Starting Copy for FOVs 0-1
# INFO: FOV 0: Copying: 0/181)
# INFO: FOV 0: Copying: 30/181)
# INFO: FOV 0: Copying: 60/181)
# INFO: FOV 0: Copying: 90/181)
# INFO: FOV 0: Copying: 120/181)
# INFO: FOV 0: Copying: 150/181)
# INFO: FOV 0: Copying: 180/181)
# INFO: FOV 0: Copying: 0/181)
# INFO: FOV 0: Copying: 30/181)
# INFO: FOV 0: Copying: 60/181)
# INFO: FOV 0: Copying: 90/181)
# INFO: FOV 0: Copying: 120/181)
# INFO: FOV 0: Copying: 150/181)
# INFO: FOV 0: Copying: 180/181)
# INFO: FOV 0 copy completed
# INFO: FOV 1: Copying: 0/181)
# INFO: FOV 1: Copying: 30/181)
# INFO: FOV 1: Copying: 60/181)
# INFO: FOV 1: Copying: 90/181)
# INFO: FOV 1: Copying: 120/181)
# INFO: FOV 1: Copying: 150/181)
# INFO: FOV 1: Copying: 180/181)
# INFO: FOV 1: Copying: 0/181)
# INFO: FOV 1: Copying: 30/181)
# INFO: FOV 1: Copying: 60/181)
# INFO: FOV 1: Copying: 90/181)
# INFO: FOV 1: Copying: 120/181)
# INFO: FOV 1: Copying: 150/181)
# INFO: FOV 1: Copying: 180/181)
# INFO: FOV 1 copy completed
# INFO: Copy completed successfully for FOVs 0-1
# INFO: After Copy context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: Processing batch in parallel with 2 workers
# INFO: FOV 0: Segmentation 0/181
# INFO: FOV 1: Segmentation 0/181
# INFO: FOV 0: Segmentation 30/181
# INFO: FOV 1: Segmentation 30/181
# INFO: FOV 0: Segmentation 60/181
# INFO: FOV 1: Segmentation 60/181
# INFO: FOV 0: Segmentation 90/181
# INFO: FOV 1: Segmentation 90/181
# INFO: FOV 0: Segmentation 120/181
# INFO: FOV 1: Segmentation 120/181
# INFO: FOV 0: Segmentation 150/181
# INFO: FOV 1: Segmentation 150/181
# INFO: FOV 0: Segmentation 180/181
# INFO: FOV 1: Segmentation 180/181
# INFO: [Worker] Segmentation context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'binarized': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: [Worker] Segmentation context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: FOV 0: Background correction 0/181
# INFO: FOV 1: Background correction 0/181
# INFO: FOV 0: Background correction 30/181
# INFO: FOV 1: Background correction 30/181
# INFO: FOV 0: Background correction 60/181
# INFO: FOV 1: Background correction 60/181
# INFO: FOV 0: Background correction 90/181
# INFO: FOV 1: Background correction 90/181
# INFO: FOV 0: Background correction 120/181
# INFO: FOV 1: Background correction 120/181
# INFO: FOV 0: Background correction 150/181
# INFO: FOV 1: Background correction 150/181
# INFO: FOV 0: Background correction 180/181
# INFO: FOV 1: Background correction 180/181
# INFO: [Worker] Correction context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'binarized': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: FOV 0: Labeling 0/181
# INFO: [Worker] Correction context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: FOV 1: Labeling 0/181
# INFO: FOV 0: Labeling 30/181
# INFO: FOV 1: Labeling 30/181
# INFO: FOV 0: Labeling 60/181
# INFO: FOV 1: Labeling 60/181
# INFO: FOV 0: Labeling 90/181
# INFO: FOV 1: Labeling 90/181
# INFO: FOV 0: Labeling 120/181
# INFO: FOV 1: Labeling 120/181
# INFO: FOV 0: Labeling 150/181
# INFO: FOV 1: Labeling 150/181
# INFO: FOV 0: Labeling 180/181
# INFO: FOV 0: Tracking 30/181
# INFO: FOV 0: Tracking 60/181
# INFO: FOV 0: Tracking 90/181
# INFO: FOV 0: Tracking 120/181
# INFO: FOV 0: Tracking 150/181
# INFO: FOV 1: Labeling 180/181
# INFO: FOV 0: Tracking 180/181
# INFO: FOV 1: Tracking 30/181
# INFO: FOV 1: Tracking 60/181
# INFO: FOV 1: Tracking 90/181
# INFO: FOV 1: Tracking 120/181
# INFO: FOV 1: Tracking 150/181
# INFO: FOV 1: Tracking 180/181
# INFO: [Worker] Tracking context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'binarized': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_seg_labeled.npy')},
#                1: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: [Worker] Tracking context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_seg_labeled.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: FOV 0: Extracting features 0/181
# INFO: FOV 1: Extracting features 0/181
# INFO: FOV 1: Extracting features 30/181
# INFO: FOV 0: Extracting features 30/181
# INFO: FOV 1: Extracting features 60/181
# INFO: FOV 0: Extracting features 60/181
# INFO: FOV 1: Extracting features 90/181
# INFO: FOV 0: Extracting features 90/181
# INFO: FOV 1: Extracting features 120/181
# INFO: FOV 0: Extracting features 120/181
# INFO: FOV 1: Extracting features 150/181
# INFO: FOV 0: Extracting features 150/181
# INFO: FOV 1: Extracting features 180/181
# INFO: [Worker] Extraction context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_traces.csv')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: Completed processing FOVs 1-1
# INFO: Merged context after worker 1-1 context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_traces.csv')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: Progress: 50%
# INFO: FOV 0: Extracting features 180/181
# INFO: [Worker] Extraction context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'binarized': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_traces.csv')},
#                1: {'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: Completed processing FOVs 0-0
# INFO: Merged context after worker 0-0 context:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'binarized': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_traces.csv')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_traces.csv')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
# INFO: Progress: 100%
# INFO: Completed processing 2/2 FOVs
# Success: True

# %%
pprint(ctx)
# Out:
# {'channels': {'fluorescence': [1], 'phase_contrast': 0},
#  'npy_paths': {0: {'binarized': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0000/250129_HuH7_fov0000_traces.csv')},
#                1: {'binarized': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_binarized.npy'),
#                    'fluorescence': [WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_raw.npy')],
#                    'fluorescence_corrected': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_fluorescence_corrected.npy'),
#                    'phase_contrast': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_phase_contrast_raw.npy'),
#                    'seg_labeled': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_seg_labeled.npy'),
#                    'traces_csv': WindowsPath('E:/250129_HuH7/fov_0001/250129_HuH7_fov0001_traces.csv')}},
#  'output_dir': WindowsPath('E:/250129_HuH7'),
#  'params': {}}
